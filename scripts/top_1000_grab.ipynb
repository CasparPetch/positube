# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path
# Out:
# ['/home/casparpetch/code/CasparPetch/positube/scripts',
#  '/home/casparpetch/code/CasparPetch/data-context-and-setup',
#  '/home/casparpetch/code/CasparPetch/positube/scripts',
#  '/home/casparpetch/.pyenv/versions/3.10.6/lib/python310.zip',
#  '/home/casparpetch/.pyenv/versions/3.10.6/lib/python3.10',
#  '/home/casparpetch/.pyenv/versions/3.10.6/lib/python3.10/lib-dynload',
#  '',
#  '/home/casparpetch/.pyenv/versions/3.10.6/envs/positube/lib/python3.10/site-packages']

# %%
# !pwd
# Out:
# /home/casparpetch/code/CasparPetch/positube/scripts

# %%
from youtubesearchpython import *
from single_video import single_video_process
import pandas as pd


def grab_channel(channel_name):
    num_videos = 10
    # channel_name = 'PewDiePie'

    channelsSearch = ChannelsSearch(channel_name, limit = 1)

    channel_id = channelsSearch.result()["result"][0]["id"]
    playlist = Playlist(playlist_from_channel_id(channel_id))

    print(f'Videos Retrieved: {len(playlist.videos)}')


    while playlist.hasMoreVideos and len(playlist.videos) < num_videos:
        print('Getting more videos...')
        playlist.getNextVideos()
        print(f'Videos Retrieved: {len(playlist.videos)}')

#     print('Done')

    ids = []
    for video in playlist.videos:
        ids.append(video["id"])
    ids = ids[:num_videos]

    infos = []
    comments = []
    for video in ids:
        info, comment = single_video_process(video)
        infos.append(info)
        comments.append(comment)
    return pd.concat(comments)
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     /home/casparpetch/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
top_subscribed = pd.read_csv("topSubscribed.csv",thousands=r',')
top_subscribed = top_subscribed[top_subscribed["Video Count"] > 0]
top_subscribed
# Out:
#      Rank             Youtube Channel  Subscribers   Video Views  Video Count  \
# 0       1                    T-Series    234000000  212900271553        18515
# 2       3  Cocomelon - Nursery Rhymes    152000000  149084178448          846
# 3       4                   SET India    150000000  137828094104       103200
# 4       5                     MrBeast    128000000   21549128785          733
# 6       7                   PewDiePie    111000000   28851883250         4694
# ..    ...                         ...          ...           ...          ...
# 995   996                     XO TEAM     11500000   11471384709         2679
# 996   997         Nirahua Music World     11500000    5997717755          788
# 997   998                     YtCrash     11400000       3825084            1
# 998   999                   Painzeiro     11400000    2143444281          946
# 999  1000                   Oum Walid     11400000    2480064722         1598
#
#            Category  Started
# 0             Music     2006
# 2         Education     2006
# 3             Shows     2006
# 4     Entertainment     2012
# 6            Gaming     2010
# ..              ...      ...
# 995  People & Blogs     2021
# 996           Music     2014
# 997       Education     2015
# 998  People & Blogs     2015
# 999  People & Blogs     2015
#
# [991 rows x 7 columns]

# %%
top_subscribed.iloc[21:]
# Out:
#      Rank                        Youtube Channel  Subscribers  Video Views  \
# 25     26  ChuChu TV Nursery Rhymes & Kids Songs     61100000  41904239949
# 26     27                              Colors TV     59300000  57825649653
# 27     28                           Dude Perfect     58600000  15294226020
# 28     29                             Movieclips     58500000  59493925856
# 29     30                  T-Series Bhakti Sagar     57300000  27004807684
# ..    ...                                    ...          ...          ...
# 995   996                                XO TEAM     11500000  11471384709
# 996   997                    Nirahua Music World     11500000   5997717755
# 997   998                                YtCrash     11400000      3825084
# 998   999                              Painzeiro     11400000   2143444281
# 999  1000                              Oum Walid     11400000   2480064722
#
#      Video Count          Category  Started
# 25           531         Education     2013
# 26        102403             Shows     2008
# 27           364            Sports     2009
# 28         39921  Film & Animation     2006
# 29         24900             Music     2011
# ..           ...               ...      ...
# 995         2679    People & Blogs     2021
# 996          788             Music     2014
# 997            1         Education     2015
# 998          946    People & Blogs     2015
# 999         1598    People & Blogs     2015
#
# [970 rows x 7 columns]

# %%
dfs = []

# %%
for row in top_subscribed.iloc[23:].iterrows():
    if row[1][4] > 50:
        print("======")
        print(row[1][1])
        print("======")
        print(f"{row[1][4]} videos listed")
        df = grab_channel(row[1][1])
        dfs.append(df)
        print(f"{len(dfs)} channels processed")
    else:
        dfs.append(0)
# Out:
# ======
# Dude Perfect
# ======
# 364 videos listed
# Videos Retrieved: 100
# tk0S7JNxnd8
# OdU_emI6KrE
# U69q07-7IgA
# R8LiwncUVnM
# T2fxrJ6ZmfY
# t9rgimw2f6Q
# _h5DdzUtrXk
# ZYW2lWLpLuo
# Ey_vGhau7ho
# Y5tYxXd4kus
# 24 channels processed
# ======
# Movieclips
# ======
# 39921 videos listed
# Videos Retrieved: 64
# jkxhRtVyn7s
# UaqSDRUrSWI
# vQk7O9Z5fE0
# JIVUUUu9cAY
# D_YzypjUzFA
# n3YE6i6Vfw4
# AtcBmM8N5z8
# eB_C9lXaYvw
# WD5VdFstH5s
# -LIDz4PijKs
# 25 channels processed
# ======
# T-Series Bhakti Sagar
# ======
# 24900 videos listed
# Videos Retrieved: 100
# L5bVUTYfePg
# Sp4JDKKYtQU
# L67WPVZ3lrk
# S9--b1W2Yzg
# -RX51O43bOo
# XdQHOhR7cFw
# HVlYLs1qKlY
# 2CaDpRbQnSo
# 3FZv_30VazU
# DJsXS59GSXs
# 26 channels processed
# ======
# Tips Official
# ======
# 4102 videos listed
# Videos Retrieved: 100
# Hgt85eKvV1w
# 6TkdXbdeZys
# GrOPR5PZTms
# KApqX8PzoqM
# Tm1OOKEcqAg
# fi2BxNk2ZY0
# yECJUuJPiyY
# 8tCkgsNvwEU
# MsPvCKypCvg
# nGf49UBSz-s
# 27 channels processed
# ======
# Marshmello
# ======
# 405 videos listed
# Videos Retrieved: 99
# fJeyqcU2lzo
# GF7qYPf35A4
# WihZjVob4v4
# uDMzx2BXm2A
# R75AFoBPBVs
# lo9q567Rgmk
# lg_w_Ev1eEc
# p6eo9Pq6ayg
# qP8Hp0Mp_ps
# 2Dtvork0ass
# 28 channels processed
# ======
# Wave Music
# ======
# 18970 videos listed
# Videos Retrieved: 100
# 3cNfL3qh2Jk
# OsRwwZZVPw4
# jXO4J6ahCrU
# f5aD9XesZ5o
# HYl0jRWnqeA
# d0jSSOkF0oM
# dsNWkb7S3BM
# eJi0470qVOQ
# yrKE4Mm5EEo
# mNGXUzMo6SA
# 29 channels processed
# ======
# Sony Music India
# ======
# 3380 videos listed
# Videos Retrieved: 100
# GZWo5aJwJ8E
# xcVB7s78JWU
# 0XRXDiAQxrQ
# ekhYtVwodfc
# lpTRepJczWI
# sZ-muDzu1TE
# eiE5Nj9tPPw
# OSHURElRTwY
# QN_4KIzlnO0
# Ys9Xc9sQvWA
# 30 channels processed
# ======
# Aaj Tak
# ======
# 233730 videos listed
# Videos Retrieved: 100
# OJyhMPL5A_s
# an-cdgqQSLI
# dQQVuT6584A
# fWuzbEywz1I
# Ncvm1nz4K_E
# ERVDvt2ruSA
# Wt9AOCQyuEE
# 12ZDXKJLELA
# iUz1FMVtrbU
# 8hgp4QZR7zI
# 31 channels processed
# ======
# EminemMusic
# ======
# 140 videos listed
# Videos Retrieved: 95
# NI4qHvsjz7I
# Zl64MRAqQxk
# cE2E6bj0Hg4
# OiBSeGoc9FQ
# qaba5mffrcw
# vs-Bsqt5ooQ
# _wN3wl473M0
# 7MO_hy5NyIw
# RjrA-slMoZ4
# EksSDDte7EM
# 32 channels processed
# ======
# El Reino Infantil
# ======
# 1410 videos listed
# Videos Retrieved: 100
# R4IAU0fvIYE
# bJPGK57kLfk
# 89nZs-UFtDk
# 5POFPs39fjQ
# mQueLyaypMY
# olzUp7cHWiY
# pV7VJ0NzO04
# 204pkJcOlIs
# fJc3DWpiAKk
# ECeUmYRgYXI
# 33 channels processed
# ======
# Ed Sheeran
# ======
# 258 videos listed
# Videos Retrieved: 100
# XGUQpwE6om0
# s5rKHbyFcVM
# RCFptlqCiY8
# _VnUGF3i2oM
# JECgz6F6vWY
# auP49MGfzKo
# QxXUv_ZR2sU
# btcErUrXkc4
# tJse76xLVic
# j6oupFD3f9I
# 34 channels processed
# ======
# LooLoo Kids - Nursery Rhymes and Children's Songs
# ======
# 607 videos listed
# Videos Retrieved: 100
# 4gduNZauyPY
# IsVsgYFzOp0
# a7idhiYpsCY
# SQSoIRGJjd0
# L6CLgY5nWI0
# ujaOu2iI6Ug
# EFcDmp2ucoQ
# 07W4v04C4bU
# STgvTf4CFs4
# 9_1OTerCK_o
# 35 channels processed
# ======
# Ariana Grande
# ======
# 146 videos listed
# Videos Retrieved: 99
# 8WsWi-BDaug
# yka6mulGMmU
# 1eI5HrQe0Fc
# BnyvDBGojoQ
# X6SuW5HhQoc
# VronettmNRI
# RiM0moNk74o
# uL52DajINdY
# F6OOVNethn8
# dDIJBIZtTyM
# 36 channels processed
# ======
# YRF
# ======
# 3475 videos listed
# Videos Retrieved: 100
# oudHNeXxYpk
# PUhe8JullLU
# O9L-hqjqEA0
# Zdz2XvJiwd4
# 5927-ed7Grc
# 2zWswSpZeeA
# PMSYWQssvGA
# XTZy32RnpEU
# tL2zOQCbZZ8
# QBO8Zv6Lg60
# 37 channels processed
# ======
# Taylor Swift
# ======
# 204 videos listed
# Videos Retrieved: 100
# XzOvgu3GPwY
# _f4yoKJL7IQ
# Hoi-PI8QpTU
# 2CnUYMmEHrs
# YvyeAwoZ76w
# anqxTwGE_nQ
# kE31ShDEOwg
# nfFujEdM0_E
# ZZtamrXjB_w
# pCH19_8E4Hw
# 38 channels processed
# ======
# BillionSurpriseToys - English Kids Songs & Cartoon
# ======
# 637 videos listed
# Videos Retrieved: 100
# iZI5Ez747wA
# SKiKNrzc9mQ
# 5-CgTDVRAwA
# 0sH1p_aNqcQ
# SJ6T5qbvyuU
# RyMLIkYbR1I
# D9OPQCNp1fM
# Oi2xsE1bCgM
# qTjicp6N9y0
# syyCgYXvCOU
# 39 channels processed
# ======
# Infobells - Hindi
# ======
# 514 videos listed
# Videos Retrieved: 100
# AT2CdUDHnY4
# i8S49qLa45M
# 6liZbg_pPYg
# SdNHuBu8zXo
# SmLLpfnD8nI
# -yYWORvCSFk
# Q2jPgSU6ktI
# L26AZdnHdd8
# qoxfUuhtdE8
# O7q25oYQoi4
# 40 channels processed
# ======
# Billie Eilish
# ======
# 51 videos listed
# Videos Retrieved: 97
# VpEITQDQRec
# mDEiSrQ0fy4
# pOX5Tdma0IE
# LPY4jB2F9Go
# P65tI0SOnY8
# AlBc606v06U
# UQphbBmXI-E
# WyrZYGmoaFM
# onT3z0lCZz8
# _JGGLJMpVks
# 41 channels processed
# ======
# JuegaGerman
# ======
# 2017 videos listed
# Videos Retrieved: 100
# QBYrdFqaKnc
# G9q0RgUdG28
# VEFTlCRgqbE
# GfdxzbJ8yTo
# T_LN48VN-Io
# 4MJ7u2krxIg
# CvWmNSSPHtU
# RGV2f50ol_8
# vKNmQOCxs_k
# XiZVA3EiyYI
# 42 channels processed
# ======
# Badabun
# ======
# 16726 videos listed
# Videos Retrieved: 100
# Fb5amRI0xEM
# zK46UEecgn4
# X4JvVemAAv4
# hVm9pUR0s-Q
# Hog7adBgOrc
# zP-C3UeplXg
# Zn6nuH2i9AQ
# L46xxd73qpg
# INxH-qR_VvU
# 5FOhYXjyK6g
# 43 channels processed
# ======
# Fernanfloo
# ======
# 542 videos listed
# Videos Retrieved: 100
# O_n6z4s7zTg
# FBEfVz-SoFw
# nl7ixNn73a0
# s-iNYzyuIcY
# zuJ-13jwH6M
# rrMQOPWolrQ
# jeOhalbyDR4
# 8LvHKr9JO6E
# BW3fTla26MM
# nnHOFsLztt4
# 44 channels processed
# ======
# Bad Bunny
# ======
# 127 videos listed
# Videos Retrieved: 100
# bef8QLNHubw
# wiFA0Ud5UtI
# wAjHQXrIj9o
# _fmk44y0oy4
# b5T7CFGMSA4
# 1TCX_Aqzoo4
# ARWg160eaX4
# saGYMhApaH8
# Cr8K88UcO0s
# 10EX-_h4pYc
# 45 channels processed
# ======
# Felipe Neto
# ======
# 3977 videos listed
# Videos Retrieved: 100
# 30lEIFaFJpA
# dcsHovu217U
# O0Ax7lnVewU
# hB-Frj6R2DM
# kEjfRS0lHRY
# wvNSN0f9Fmw
# _Yht8j7qCzA
# E6sFv6ON7Lo
# 9PrqhMSvEtE
# d3pN1-4bL08
# 46 channels processed
# ======
# SonyMusicIndiaVEVO
# ======
# 3366 videos listed
# Videos Retrieved: 100
# VFYWevLzl68
# mupFVwXSH_c
# Ooxp4Jc-zNw
# 5c9iFQZE74E
# 2I-pr2tXnp4
# fSy4FFMhrgM
# vIQupo30hdI
# 5T2Y649cbFE
# p33m8C3GmEU
# 1htrqDwi6vo
# 47 channels processed
# ======
# BRIGHT SIDE
# ======
# 5173 videos listed
# Videos Retrieved: 100
# ZtjWjns9AAM
# n0QxKjClY0c
# HMspkpC7Dfk
# pagVK6bl6TI
# R9x_aL-cl-o
# yr6gQLZEybs
# imjIcxQT7_4
# bUlz7v8R7QA
# SR43LCbN6Hs
# E86qq__1Hso
# 48 channels processed
# ======
# Get Movies
# ======
# 3160 videos listed
# Videos Retrieved: 100
# 2vx8vaU1i6Y
# 9UKOGDFckmM
# -N4EBg0Qi8g
# i4EMPPa4GCY
# FDEvmW3ZqiE
# Ue7Z9Vv5cec
# hLWrQQMpWpM
# 9Lvu8og7NWQ
# 4vl0F0IV-Ik
# bUPY728hlsA
# 49 channels processed
# ======
# Você Sabia?
# ======
# 1444 videos listed
# Videos Retrieved: 100
# GYSQP2QBJeM
# aTz7Z4p-HBY
# 6VfashcQUZs
# tnV9aSlo7qU
# F-2uzhgIKYo
# dN0iBo7418k
# m5EXwMLiBj0
# hPlendP66bc
# prMpDBVLLxA
# bgbuT7XrQLg
# 50 channels processed
# ======
# whinderssonnunes
# ======
# 524 videos listed
# Videos Retrieved: 100
# n8ktlmXnRv4
# C2DTfOPdntQ
# NjdiAGZNSLQ
# XEZPSznKImk
# P6arALcZuOU
# 7W0GiidWGpk
# lftaA-63Vcs
# hFy1nh2NkuQ
# LfSwOwf17kU
# jlZURuVghCQ
# 51 channels processed
# ======
# Shemaroo
# ======
# 10697 videos listed
# Videos Retrieved: 100
# -QspdA84ryc
# 9Ol9BDNyJPc
# hLGIWoZyaco
# TtVzEP4PbtE
# D9BRlw-mah0
# -KcSepHXMDw
# yDyrg2a-WDw
# Vo9LpntX0E4
# _GTAZWZy5uA
# mQqT1b5uSJ8
# 52 channels processed
# ======
# A4
# ======
# 709 videos listed
# Videos Retrieved: 100
# Be4OXgW0Kio
# BXQ9nLvEJdU
# 5m6VQaXZ60Y
# w9RkMdZ0wxk
# WZ9oVWo-hBw
# R9Vc6_ZSNkE
# Vrr_P4eTKa4
# wNZV_aQEYZo
# EpVWHm-SQWI
# zamd2YOApDE
# 53 channels processed
# ======
# Katy Perry
# ======
# 120 videos listed
# Videos Retrieved: 97
# CWOqqjO3VnQ
# 44dzk07JWbw
# bZCxOno5VZ8
# Dm7iAWk9aLU
# d8GuVx--bsk
# tpbNnXYDwmg
# 903i4dEZZTA
# VOT-iMaI9wU
# f-tPtKJujrY
# JZXrkS6KPT4
# 54 channels processed
# ======
# HolaSoyGerman.
# ======
# 136 videos listed
# Videos Retrieved: 100
# 52EpErqNP80
# 4BkxCvg2spU
# Lr08OBSIMv0
# oz0hdMkQ_9w
# sqAtLg-W_dA
# YjNF9Rj4tN8
# D62HGy72HC0
# CXxNf2cfbuM
# u-ZumdtYyio
# shYqdMw5jeY
# 55 channels processed
# ======
# Alan Walker
# ======
# 364 videos listed
# Videos Retrieved: 100
# 8mvqhUBaNVk
# Yc2ICHZklUc
# y_d7ftKk9Go
# 9eMnTY2wl70
# Yxcm0DdJ2zs
# gzpzxKuCIu4
# x6mupI8Dd6Q
# l1krMWx9GXE
# KtBzx_SOgWQ
# 7DJoEYQjzaI
# 56 channels processed
# ======
# Voot Kids
# ======
# 3923 videos listed
# Videos Retrieved: 50
# 9abMEj0STgE
# K2ZTfoSurxA
# O7cCbnMJI88
# r6pZfQY93Y4
# tTbsj6SzmI0
# i534Oolt330
# -0qN1ySZ_8g
# najwnENnxZc
# iOBxwpAvrr0
# ki0XKZIPGoU
# 57 channels processed
# ======
# Like Nastya Show
# ======
# 606 videos listed
# Videos Retrieved: 100
# pG-j4lXIsyw
# uvHBReJz6rI
# YyYTSa_N09U
# mLZAXJzlWbY
# m0nYQQYe8So
# w23lAA9jT7Q
# kfsJ3LPw_UI
# 8ipbhxkGe_g
# 10rl81tQcLU
# IxXN8oRyAqo
# 58 channels processed
# ======
# ABS-CBN Entertainment
# ======
# 185775 videos listed
# Videos Retrieved: 42
# ZmrWGX9DCDk
# t3YbeRsL7rg
# 7mYf98XWOzo
# G5uh8HtCAps
# cKrFaFcUhhA
# QJ2CaL-CRh8
# dy653f4ykPg
# ivYvQeZJ1w8
# xZH0jxnp0zo
# Xt8b7dGqae8
# 59 channels processed
# ======
# Speed Records
# ======
# 10608 videos listed
# Videos Retrieved: 99
# ZYA6rTUgk2I
# b5C_4g1oPWw
# tcMxF04n7iw
# rhPNgijqpW0
# LMCPeMFEY7w
# TN-3sYwRS4k
# 5mMsncrIf2s
# VVKSWvk8hYo
# ZrAKw2ytrmY
# EfosCHEKfUY
# 60 channels processed
# ======
# Rihanna
# ======
# 82 videos listed
# Videos Retrieved: 94
# 0NZ6A-X6taA
# l85nFZuipJ8
# k5E6CExu204
# 3n5tK-OpInk
# EPb4pCckL58
# dgPMmx7VHFg
# EekTOIb0lc8
# UWCf7GNy6cc
# Mx_OexsUI2M
# wYfWVN_UClE
# 61 channels processed
# ======
# Маша и Медведь
# ======
# 1281 videos listed
# Videos Retrieved: 100
# XyXXLa-1u40
# UxnDnpTqVkA
# 53nepxdXSfU
# 89t0nAWdP3U
# w-8zg1dRazg
# lCsPRf-Nbk0
# SrWqtRR_bdA
# 8LqGsjXfzIo
# _-timwx6YeM
# TMIt_Crji94
# 62 channels processed
# ======
# Little Baby Bum - Nursery Rhymes & Kids Songs
# ======
# 2245 videos listed
# Videos Retrieved: 100
# Ur0CbgD2OEU
# SFaa1JPX1VM
# UnL3309U0xE
# K2J6CiJU-90
# nGwj6ZMFTYY
# jiQhGtQ0Z6I
# ETyqmxXGhRI
# _wtFc0EgmqI
# 2WHJERkI2k0
# MZPnl2Q18Hk
# 63 channels processed
# ======
# elrubiusOMG
# ======
# 711 videos listed
# Videos Retrieved: 99
# -6LZMizP2YU
# dwA716rQafk
# 6jHJZ3AmKVA
# HdccnA0Njn8
# fUwOqo0ZDvg
# h0EmwU7upVY
# uP_NGr3NhvI
# 1vPUcFfnIhM
# gOl7U1k1ZFA
# jg0H9uvZa-c
# 64 channels processed
# ======
# Shakira
# ======
# 307 videos listed
# Videos Retrieved: 100
# iX0yz0wJC_w
# kZFlVdJ79rw
# cCoy07NA7hk
# y_iU0vAPggc
# PWmJhh_qTSY
# ToQ5jVj1Ppo
# cqVNQ8B6jEE
# fvQ7uaM554g
# hFkuPpc7ymo
# c8HRH0gvJDY
# 65 channels processed
# ======
# Luisito Comunica
# ======
# 1194 videos listed
# Videos Retrieved: 100
# rVEgtdAzOE0
# Sr15A0AA0UY
# BinIp2v-jgg
# qyOW2ietK3A
# f1yIX7EMhQE
# qxx-rjDIEuE
# K4FTCOn83SI
# tlfxi2nyaKw
# QzHOv1-8dNg
# HtFyFVVpKtc
# 66 channels processed
# ======
# Ishtar Music
# ======
# 4582 videos listed
# Videos Retrieved: 100
# Zsj6O347gu4
# uVyIOvk_wGE
# 4VGu5BSdty0
# X4a6hmVLtr4
# LCCfk29gZwk
# 4396zs9P9BQ
# n1P1XokK5HQ
# 7T-84swKc9U
# V-AL_lz2e30
# wVwpkHd-uBY
# 67 channels processed
# ======
# Kimberly Loaiza
# ======
# 250 videos listed
# Videos Retrieved: 100
# M5_f3or8U3s
# YLIQQcNtgpA
# cPctiOUM3ds
# b72HTQS3YPE
# C9c-Y2ORb6Y
# nDBLC1UkrIQ
# 4AAWf5PGjUo
# ZwtBTpy7JLA
# 9uvAPRfA8PI
# O1tSvHLJWWc
# 68 channels processed
# ======
# LUCCAS NETO - LUCCAS TOON
# ======
# 1985 videos listed
# Videos Retrieved: 100
# usF0fte0W88
# 69LSQTD6EMw
# k7kIEXTVK9s
# pjGnjk9KE8U
# ao9kWK7_BZs
# WWZ6LOWOiu4
# gre97bwkVjo
# lrte2hYLWmE
# 1frMT3nHmhk
# kk5DIbULIL8
# 69 channels processed
# ======
# ARY Digital HD
# ======
# 88409 videos listed
# Videos Retrieved: 100
# qAns3pdFI5s
# IFtIfcgyJEo
# aO1E80DxdCQ
# PDz57mLA3p8
# LihO-eYDoMg
# LRjlMU8GaFI
# UX6sZLbr6PU
# XqxLqJsdhiE
# C1taMrPcmGk
# 4ZGJU4VAN9E
# 70 channels processed
# ======
# Masha and The Bear
# ======
# 1035 videos listed
# Videos Retrieved: 100
# y1Z46IlWVcM
# MehkWJDD-5E
# jOmPTNumdiA
# y5ew7kX8B2c
# QDNNYB-83Gk
# iO8EW9dnuWU
# n6Pe5te2vOU
# 6INWfRK9vEI
# u8xdzeuV_Jk
# _OCSYVRm1S8
# 71 channels processed
# ======
# XXXTENTACION
# ======
# 129 videos listed
# Videos Retrieved: 100
# hyiku5iCJeU
# L_BgfkJtU-A
# JlcahUU_NwY
# GIeYx-huuUA
# _afCucJNyQ0
# 0n1bu8o_jXc
# s1qMre0Il0c
# Wkbx8qYjU8Q
# JTbMeUmQuWY
# M1DZE8VL4gE
# 72 channels processed
# ======
# GR6 EXPLODE
# ======
# 4134 videos listed
# Videos Retrieved: 100
# Fwc_qSKZSxs
# KbxL5iDa9FE
# B3q_I0vuZu0
# E5Qw1MlkaFk
# lQE7K7WzmUY
# xxMwXl6Sbvk
# L-iY1KNYSng
# 1DGsclIrgBE
# tVqAe8UzDdw
# TJuUjGS7YRI
# 73 channels processed
# ======
# Toys and Colors
# ======
# 905 videos listed
# Videos Retrieved: 100
# Z9AKv2o-z50
# nXWXLGDz_iw
# FwEBshclYqU
# cYyhnHErFq4
# _mCOCkmyU0I
# Q1L8eXVLbUs
# zb0k_yw4w4w
# t5EVv7t59oc
# 0R9SfhemiPo
# N4Ro6HErj4g
# 74 channels processed
# ======
# TheEllenShow
# ======
# 14993 videos listed
# Videos Retrieved: 100
# vTE1ttqcBks
# DXGiVlEmUOk
# 1rJaEf1UFgw
# TBEdQReTGFs
# mzGJHQiQW2E
# SjjEU4V80nA
# BOL65z3SlRI
# 2VzgTMT2pnM
# xpoPoNLBZ7E
# tXDTApUZiSY
# 75 channels processed
# ======
# WorkpointOfficial
# ======
# 69696 videos listed
# Videos Retrieved: 100
# pF-k10Ma9e0
# dieRV7IED-Y
# Yjlp8UHarXA
# rCrJ5rVL5do
# NieIBXjDT0w
# uEQHdRsuido
# dqi16mkspP0
# TtqOx7w3388
# eIOpMVt3Kd8
# zJ1DRv0MX68
# 76 channels processed
# ======
# One Direction
# ======
# 157 videos listed
# Videos Retrieved: 98
# AsmHz9JCU4M
# AGDlC3VDVCc
# HBttoBTxkAs
# JAERpGGh-wA
# dTvgQ7-jPYk
# fJXVQ3KvZRM
# 6poJkzAl6Ss
# FwjshZCtUS0
# HKVEJ4LhUAE
# L47mRyhxsBw
# 77 channels processed
# ======
# CarryMinati
# ======
# 180 videos listed
# Videos Retrieved: 100
# iFtH6g5HEVM
# D6HAgkLImUQ
# IoTL9xZOdP0
# KlLxJ1FrOlI
# pmj9gF7H_lQ
# l6BChpns5w8
# -LIMVVfRp6Q
# G6qLfTA2PFw
# 0jUj3rfO7eM
# xLjMzNKUXKs
# 78 channels processed
# ======
# Daddy Yankee
# ======
# 471 videos listed
# Videos Retrieved: 100
# 4pvC5JvPztE
# P4LkBQHkLMo
# 6Tly30J8fdM
# hE4EFjQlIYY
# t2M1BSRB714
# fhNc9p5xhtU
# zR9Nq3MFfLA
# ZKPZhwbHPm4
# JBHM5Ihv8t0
# BlxKDtG3QMM
# 79 channels processed
# ======
# shfa2 - شفا
# ======
# 1468 videos listed
# Videos Retrieved: 100
# LvjmqlHp3OM
# HKcZkiE8CrI
# 2G0MIqOBgZ0
# twP_wBT7GuQ
# oNZsaoXUKjo
# BAcjpLkmnCQ
# AYdE28tMbGM
# t3BwDD72Im4
# u8eX4Ui-6n8
# nzCxXbhr-QA
# 80 channels processed
# ======
# Super Simple Songs - Kids Songs
# ======
# 647 videos listed
# Videos Retrieved: 100
# KB21-0UPGqQ
# yTGCJCwVI5w
# HF5vGPU4vUo
# nOlY5NJ6LhY
# XwaJ_ly56cg
# vmSN7TatwaM
# ZN678PdH1RM
# 7KYDS25qzW0
# uAhagTmM-sk
# T_to0yV0WIk
# 81 channels processed
# ======
# TEDx Talks
# ======
# 191506 videos listed
# Videos Retrieved: 100
# ZqPWaeNHYfc
# vuUcn4iOZNI
# sdBJEhiH_gM
# -V-tqJyxp_8
# wNmeacbSQcE
# M5m0cRUcS2w
# jY77KKqhdds
# Nk8VPNrSkDY
# JIYje17oRJg
# 5x6WTyPIums
# 82 channels processed
# ======
# shfa
# ======
# 920 videos listed
# Videos Retrieved: 100
# fFWcg613Z-o
# X3MLJD18qvg
# RpnIX9Z5j80
# uT4B-nNX5J4
# BPl60Q_2knE
# bzBSH8gVxyI
# Zl9PXw__iM4
# EdfxhSzX7XU
# 9ripF3SPeQE
# YFyV4XN9b-A
# 83 channels processed
# ======
# Jkk Entertainment
# ======
# 207 videos listed
# Videos Retrieved: 100
# -dthzhfD494
# VAOWqhX80c0
# MNVYHgaqEUg
# 9PTQbZPRGOw
# 6TOr-N8eyUQ
# fcgtaclXey8
# RaE1z1EI_Ww
# 1kRuIVNcnjI
# kbipLHwHr0k
# 3ivKJkWEsIE
# 84 channels processed
# ======
# HAR PAL GEO
# ======
# 80499 videos listed
# Videos Retrieved: 100
# izE1UNEmcMo
# BWL86gYif4U
# y7z0J8Ufz4s
# 5wyWj1c5WEw
# 8GlkXhyB8a0
# bWBvupnYFPQ
# pWGqhx0gMsI
# o3LeeHYgYHU
# 9qKyZo_teYk
# O08QEAd3PF0
# 85 channels processed
# ======
# Mikecrack
# ======
# 1811 videos listed
# Videos Retrieved: 100
# goG2o0dfgQw
# NLZsPnSswdc
# qVT4Q_oyW40
# YJKan60dS4Y
# A5KDG41UxlI
# upQnZyR9Gpc
# 0Hkw8mqryI4
# 3rdBdMEpgQQ
# YAGV7-qVYEo
# 8z5C1OVtRgs
# 86 channels processed
# ======
# Maroon 5
# ======
# 163 videos listed
# Videos Retrieved: 100
# -3-mG5nui5o
# hiE2su_BapQ
# 3CI20GQhekE
# JANJl2c2oY8
# 3u9Q-Z672w4
# Ntc2XNAGGMQ
# YoSsWLB6nCk
# -DWksaMuQOw
# hPG2nU0UsTA
# GStRLppm_0k
# 87 channels processed
# ======
# Goldmines Gaane Sune Ansune
# ======
# 3406 videos listed
# Videos Retrieved: 100
# Xwk1MgbFyPk
# MQZjXRUi4L4
# YWYT6G2Yfes
# Yfvbp4mxPLM
# RTcq5UsmNuM
# QV4t7MuRlTE
# 3vlmf28TweA
# bBkd9zpNtP0
# dermfLouXZU
# bvxos22mT0E
# 88 channels processed
# ======
# Bruno Mars
# ======
# 99 videos listed
# Videos Retrieved: 99
# 6ZPzqZoRrtk
# 1DtiIODxkyI
# BNro3uBlqVg
# IPNEjhBlMM4
# -nt_u4vo-DI
# eEQMtIX61LA
# 8yATbsjxbLo
# IQQ-87RSCRM
# nAUwKeO93bY
# MfpFNRO_hGY
# 89 channels processed
# ======
# ช่อง one31
# ======
# 104458 videos listed
# Videos Retrieved: 95
# wHHo1Tu2PZ8
# thluhxgZ5tU
# MP72YgBY1_E
# SRZTryrtKtk
# NfPm66kvTUw
# go43aYKPPGk
# kvnPhYRndaY
# s33rrv3nmcM
# 9sNdpkH0rxU
# -hizYwZ1PrY
# 90 channels processed
# ======
# Like Nastya ESP
# ======
# 691 videos listed
# Videos Retrieved: 100
# d-1UWz-y8yA
# 7AESydd9pmc
# 4QZya_qGLHU
# HWXLLgo9c4E
# TKjTj2QXmp4
# 2d7_WxPpBP8
# gZtIa2SMAOk
# AZWPOylZT-U
# 7BCy56hmH5M
# PjkTuZIv_lI
# 91 channels processed
# ======
# Ozuna
# ======
# 162 videos listed
# Videos Retrieved: 100
# XTVrMuvXLnI
# ZuUlzb23GBU
# 5xWtisNHPhY
# Mp0d3xnNeok
# qdvYRpyF6D8
# LpULpg_k2eE
# sf5DraUthZY
# 2KmgbBKtXPA
# dH7XxtPRlMI
# 1-H7RiwHnZo
# 92 channels processed
# ======
# Maria Clara & JP
# ======
# 693 videos listed
# Videos Retrieved: 100
# pS5V5hETcBM
# coae2JoRlF8
# cNRmFbyIYdA
# bZW-drukNuA
# TgMvdcBBezI
# H5q44BLvXFo
# uWtGisT8ZYU
# cbbNOjxXZeo
# kQOyL79WC-o
# 1LBha7R_sPo
# 93 channels processed
# ======
# Sony PAL
# ======
# 21627 videos listed
# Videos Retrieved: 67
# pkwcmDuqh3c
# 4Ik4xhZkqjc
# Swuw-XAuu-4
# FG5u5Pgnss4
# e4mco2WwWlM
# UuIfn8BSjaY
# ZtnJWgO1Kis
# rnZUb4Nb7rc
# PUxILc6jNF8
# u332moK1Yvs
# 94 channels processed
# ======
# YouTube
# ======
# 620 videos listed
# Videos Retrieved: 100
# -G-XKgjTp14
# zKGszxaWtyQ
# LFJ5f6cVIHY
# p3kWz99gcZc
# nBMMSQzOSqs
# 29OUwBbbWlc
# R6iH1lBQxdM
# UbeRikTKDeA
# VeqSsH1PlqU
# cPGD5-DECko
# 95 channels processed
# ======
# Ultra Bollywood
# ======
# 9424 videos listed
# Videos Retrieved: 100
# enCt8-Hy0NA
# DHEkAYZg0Rs
# m8c2ZDH83q8
# TSc8YCDeWCA
# FVJTgSaTWnk
# wNQIWSrX6rA
# 7Gju4EXI58A
# h-THrEAXGs0
# 1wy2Z-MW-Ao
# 7cOPoEJHscs
# 96 channels processed
# ======
# ABP NEWS
# ======
# 253628 videos listed
# Videos Retrieved: 100
# fnYq3qLOjBc
# xfImj2IJypM
# 5FA5Rifv_E0
# qNWAPn0cHts
# E0XmKzDSyF8
# wxpkPVakO2Y
# aHqOtSY7w5Q
# kZsldORwTEA
# L6Oy19uvUmg
# WFvYydVk8P0
# 97 channels processed
# ======
# Total Gaming
# ======
# 1137 videos listed
# Videos Retrieved: 100
# MP1Vu6Vlamc
# 4zFxKr2_Rng
# JUieNvuvrEM
# 5Cc9MBrvgAo
# NpsZSgbAcGo
# DGyDgGI5v0s
# qJBZyF-jf5M
# Kdg0YPD7NDA
# 5TheEK5HIzo
# D1kZLfAvjCI
# 98 channels processed
# ======
# Markiplier
# ======
# 5392 videos listed
# Videos Retrieved: 100
# OFxTS9RbOtY
# z5pKkkvNrTk
# 7UfDJFzSPgA
# -MUN67sKbBg
# 5xknXnosc7Y
# 8DvptGwxPGE
# AekL7z6li2U
# ya6XedyPTvg
# pSuUbhb2Vws
# C7__2tjWQTU
# 99 channels processed
# ======
# Ryan's World
# ======
# 2294 videos listed
# Videos Retrieved: 100
# GcuhjpvHcpI
# 9dKAOU6IZKM
# iNi69wh3KKw
# HT12_LiYVQc
# GbFqO1W4F_4
# fxbwWenefsU
# AdM1Ftt1JOo
# r1S_TS8KBSg
# 5wP-SarbKwo
# sFfRLAbb1NE
# 100 channels processed
# ======
# J Balvin
# ======
# 134 videos listed
# Videos Retrieved: 100
# fXWd3fzIey8
# JKTJGYGy74s
# PgiTBSfuP1o
# CRdOTohfK_E
# eDjkD31ZHTw
# Zu8akRdcVio
# 9zoDqdAGSIM
# G2o5VTd4xrg
# rNfwfUcg6Gg
# LXEB99cR59k
# 101 channels processed
# ======
# Vlad và Niki
# ======
# 457 videos listed
# Videos Retrieved: 100
# z0Q69rcQZqQ
# tD9DVwEP9tQ
# bOK1cn8kd_E
# 7wHcOimYnw8
# DHPcIdwucvQ
# GrysOi1R__E
# Ab6SvEUc_RY
# LCwO1QfS9Gc
# fdWv2ImJ36M
# ZRRxvHBwaW8
# 102 channels processed
# ======
# Geet MP3
# ======
# 614 videos listed
# Videos Retrieved: 100
# jsBx5xImX88
# bMQ-HrowlsQ
# OVi2RiMyFTk
# sZ8nxnsjh9Y
# 5ZRxNnWqR8s
# Je5_Dcw6860
# NV_bJt2SCsU
# RUR77lSux1A
# 2jxV9QbT0nI
# sUWuk0_v9lU
# 103 channels processed
# ======
# Desi Music Factory
# ======
# 129 videos listed
# Videos Retrieved: 100
# rRyeljxLsY0

# %%
len(dfs)
# Out:
# 23

# %%
dfs.append(0)
