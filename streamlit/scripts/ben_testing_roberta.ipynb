# %%
from single_video import single_video_process
from roberta_demo_day import roberta
import pandas as pd

# %%
df = single_video_process('E_fOkSuwsuE')
# Out:
# E_fOkSuwsuE

# %%
df1 = df[1]

# %%
df1
# Out:
#                                               comment  ...     video_id
# 0   I ordered phall several times at best indian r...  ...  E_fOkSuwsuE
# 1   As a Jamaican jerk chicken is actually suppose...  ...  E_fOkSuwsuE
# 2   As a West Indian, forgetting the scotch bonnet...  ...  E_fOkSuwsuE
# 3        PaPa still the spiciest thing in this video.  ...  E_fOkSuwsuE
# 4                    They look so fiery and delicious  ...  E_fOkSuwsuE
# ..                                                ...  ...          ...
# 95  Joshua, Jamaican me crazy for not using Scotch...  ...  E_fOkSuwsuE
# 96  As a non-spicy food lover, these recipes look ...  ...  E_fOkSuwsuE
# 97  This would be a perfect video to collaborate w...  ...  E_fOkSuwsuE
# 98  I remember a BIR restaurant a gang of us used ...  ...  E_fOkSuwsuE
# 99  Hey here's a idea for a show you could cook fo...  ...  E_fOkSuwsuE
#
# [100 rows x 7 columns]

# %%
roberta(df1)
# Out:
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.
# /Users/macbook/.pyenv/versions/3.10.6/envs/positube/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment.
# ...
