# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
top_subscribed = pd.read_csv("/home/casparpetch/code/CasparPetch/positube/raw_data/topSubscribed.csv",thousands=r',')
top_subscribed
# Out:
#      Rank             Youtube Channel  Subscribers   Video Views  Video Count  \
# 0       1                    T-Series    234000000  212900271553        18515
# 1       2              YouTube Movies    161000000             0            0
# 2       3  Cocomelon - Nursery Rhymes    152000000  149084178448          846
# 3       4                   SET India    150000000  137828094104       103200
# 4       5                     MrBeast    128000000   21549128785          733
# ..    ...                         ...          ...           ...          ...
# 995   996                     XO TEAM     11500000   11471384709         2679
# 996   997         Nirahua Music World     11500000    5997717755          788
# 997   998                     YtCrash     11400000       3825084            1
# 998   999                   Painzeiro     11400000    2143444281          946
# 999  1000                   Oum Walid     11400000    2480064722         1598
#
#              Category  Started
# ...

# %%
top_1000_1 = pd.read_csv("final_channel_data.csv")
top_1000_1 = top_1000_1[["comment", "author", "likecount", "date", "replies", "video_id", "channel_id"]]
top_1000_1
# Out:
#                                                  comment             author  \
# 0      Razik mujawar Is Not Just A History Breaker He...  Rk Vines Bhojpuri
# 1         Your voice has a feeling that touch my heart ♥     Ordinary Being
# 2      Forever inspired by your melody, forever capti...       Arnob short
# 3                  Mah bro Razik ! So proud of you man !     Karasama Beats
# 4                         Beautiful  song... Just wow ❤❤         BD CLASH R
# ...                                                  ...                ...
# 79379  Because of Zack kindness he will soon become t...        Jhansi Rani
# 79380           You are doing great work ZHC team 👏👍🥳❤🇮🇳       Robin Rathva
# 79381  Keep spreading kindness and the kindness will ...              Grant
# 79382  ZHC- Today I am going to customize a cafe \nMe...            Kit Cat
# 79383  A dream collaboration would be ZHC and Mr Beas...     ever free fire
#
# ...

# %%
top_1000_2 = pd.read_csv("final_channel_data2.csv")
top_1000_2 = top_1000_2[["comment", "author", "likecount", "date", "replies", "video_id", "channel_id"]]
top_1000_2
# Out:
#                                                  comment            author  \
# 0                       rigen kalah gara gara kenta wkwk       Bagas Hanif
# 1      Yehhh team kang deny dpt 7jt smua team dpt had...       Hesti Fhany
# 2      Seru nih kalo ada kapten emosian rigen, oki, b...    manusia planet
# 3      Gokil Kenta lucu terus, clue nya selalu out of...           Mini Me
# 4      yg terakhir out of the box banget. kebanyakan ...       Bagas Hanif
# ...                                                  ...               ...
# 12530      Ye mera super hero I miss you appu beta🙏🙏🙏😭😭😭  DEEPA FATERPEKAR
# 12531                                     Va super movis       Dita Dindor
# 12532               First comment me hit like kardo yaar      tractor fans
# 12533                                     🥀🌷🇮🇳🌷🥀\nComedy  Taslim Choudhary
# 12534                    Bahut hi comedy movies hai😅😅😅😅😅           A Films
#
# ...

# %%
result = pd.concat([top_1000_1, top_1000_2])
result
# Out:
#                                                  comment             author  \
# 0      Razik mujawar Is Not Just A History Breaker He...  Rk Vines Bhojpuri
# 1         Your voice has a feeling that touch my heart ♥     Ordinary Being
# 2      Forever inspired by your melody, forever capti...       Arnob short
# 3                  Mah bro Razik ! So proud of you man !     Karasama Beats
# 4                         Beautiful  song... Just wow ❤❤         BD CLASH R
# ...                                                  ...                ...
# 12530      Ye mera super hero I miss you appu beta🙏🙏🙏😭😭😭   DEEPA FATERPEKAR
# 12531                                     Va super movis        Dita Dindor
# 12532               First comment me hit like kardo yaar       tractor fans
# 12533                                     🥀🌷🇮🇳🌷🥀\nComedy   Taslim Choudhary
# 12534                    Bahut hi comedy movies hai😅😅😅😅😅            A Films
#
# ...

# %%
result.value_counts("channel_id")
# Out:
# channel_id
# ZHC                  2475
# Mark Rober            995
# jacksepticeye         994
# VanossGaming          994
# MrBeast Gaming        993
#                      ...
# AboFlah                 4
# Ch3Thailand             2
# ABPLIVE                 2
# A4                      1
# WorkpointOfficial       1
# Name: count, Length: 232, dtype: int64

# %%
from roberta_demo_day import roberta
# Out:
# 2023-06-14 10:07:43.844235: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-14 10:07:44.998320: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-06-14 10:07:44.998840: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-06-14 10:07:45.130737: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
result.head(10)
# Out:
#                                              comment             author  \
# 0  Razik mujawar Is Not Just A History Breaker He...  Rk Vines Bhojpuri
# 1     Your voice has a feeling that touch my heart ♥     Ordinary Being
# 2  Forever inspired by your melody, forever capti...       Arnob short
# 3              Mah bro Razik ! So proud of you man !     Karasama Beats
# 4                     Beautiful  song... Just wow ❤❤         BD CLASH R
# 5  Razikk!!! Mann many more to come ❤❤❤❤ woww rea...    Mandar sarnobat
# 6           Hard Work Pay Off Razik Bhai 🥺❤️🦋🔥✨✍️🍁🍁🍁        FMA Rockers
# 7                                      So good! ❤️❤️        Ashwini Vas
# 8                                      Nice song ❤❤❤         🌾༄𝐘𝐔𝐒𝐔𝐅࿐ 🌿
# 9                                      Wow amazing 😍     Mr Birju Vlogs
#
#    likecount                  date  replies     video_id channel_id
# 0        3.0  2023-06-13T11:56:10Z      0.0  vjOUtLFlwxY   T-Series
# ...

# %%
comments, scores = roberta(result.head(10))
scores
# Out:
# 2023-06-14 10:07:57.804182: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-06-14 10:07:57.805083: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-06-14 10:07:57.805414: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (LAPTOP-V03TBCL4): /proc/driver/nvidia/version does not exist
# 2023-06-14 10:07:57.808332: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# ...

# %%
comments
# Out:
#                                              Comment Sentiment  Negative (%)  \
# 0  Razik mujawar Is Not Just A History Breaker He...   Neutral          0.93
# 1     Your voice has a feeling that touch my heart ♥  Positive          0.15
# 2  Forever inspired by your melody, forever capti...  Positive          0.31
# 3              Mah bro Razik ! So proud of you man !  Positive          0.13
# 4                     Beautiful  song... Just wow ❤❤  Positive          0.25
# 5  Razikk!!! Mann many more to come ❤❤❤❤ woww rea...  Positive          0.12
# 6           Hard Work Pay Off Razik Bhai 🥺❤️🦋🔥✨✍️🍁🍁🍁  Positive          0.15
# 7                                      So good! ❤️❤️  Positive          0.15
# 8                                      Nice song ❤❤❤  Positive          0.18
# 9                                      Wow amazing 😍  Positive          0.31
#
#    Neutral (%)  Positive (%)  Scaler_value  weighted_SV  weight     video_id  \
# ...

# %%
"video_id" in list(comments.columns)
# Out:
# True
