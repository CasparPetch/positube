# %%
# !pip install google-api-python-client pandas
# Out:
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.88.0-py2.py3-none-any.whl (11.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 23.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pandas in /Users/macbook/.pyenv/versions/3.10.6/envs/positube/lib/python3.10/site-packages (2.0.2)
# Collecting httplib2<1dev,>=0.15.0 (from google-api-python-client)
#   Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /Users/macbook/.pyenv/versions/3.10.6/envs/positube/lib/python3.10/site-packages (from google-api-python-client) (2.19.1)
# Collecting google-auth-httplib2>=0.1.0 (from google-api-python-client)
#   Downloading google_auth_httplib2-0.1.0-py2.py3-none-any.whl (9.3 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 (from google-api-python-client)
#   Using cached google_api_core-2.11.0-py3-none-any.whl (120 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client)
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/macbook/.pyenv/versions/3.10.6/envs/positube/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/macbook/.pyenv/versions/3.10.6/envs/positube/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/macbook/.pyenv/versions/3.10.6/envs/positube/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/macbook/.pyenv/versions/3.10.6/envs/positube/lib/python3.10/site-packages (from pandas) (1.24.3)
# Collecting googleapis-common-protos<2.0dev,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client)
#   Using cached googleapis_common_protos-1.59.0-py2.py3-none-any.whl (223 kB)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /Users/macbook/.pyenv/versions/3.10.6/envs/positube/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.19.6)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /Users/macbook/.pyenv/versions/3.10.6/envs/positube/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/macbook/.pyenv/versions/3.10.6/envs/positube/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/macbook/.pyenv/versions/3.10.6/envs/positube/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/macbook/.pyenv/versions/3.10.6/envs/positube/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: six>=1.9.0 in /Users/macbook/.pyenv/versions/3.10.6/envs/positube/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (1.16.0)
# Requirement already satisfied: urllib3<2.0 in /Users/macbook/.pyenv/versions/3.10.6/envs/positube/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (1.26.16)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/macbook/.pyenv/versions/3.10.6/envs/positube/lib/python3.10/site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/macbook/.pyenv/versions/3.10.6/envs/positube/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/macbook/.pyenv/versions/3.10.6/envs/positube/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/macbook/.pyenv/versions/3.10.6/envs/positube/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/macbook/.pyenv/versions/3.10.6/envs/positube/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2023.5.7)
# Installing collected packages: uritemplate, httplib2, googleapis-common-protos, google-auth-httplib2, google-api-core, google-api-python-client
# Successfully installed google-api-core-2.11.0 google-api-python-client-2.88.0 google-auth-httplib2-0.1.0 googleapis-common-protos-1.59.0 httplib2-0.22.0 uritemplate-4.1.1

# %%
import os
import pandas as pd
from googleapiclient.discovery import build

# %%
api_key = os.environ['API_KEY']
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
search_response = youtube.search().list(
    part='snippet',
    q='illuminati',
    type='video',
    maxResults=100
).execute()

# %%
videos = []
for item in search_response['items']:
    video = {
        'Title': item['snippet']['title'],
        'Channel': item['snippet']['channelTitle'],
        'Published At': item['snippet']['publishedAt']
    }
    videos.append(video)

df = pd.DataFrame(videos)
print(df)
# Out:
#                                                 Title  \
# 0                             What Is The Illuminati?
# 1    The video the Illuminati doesn’t want you to see
# 2                   What Actually ARE the Illuminati?
# 3              Are the illuminati real? - Chip Berlet
# 4   How the Illuminati conspiracy theory started |...
# 5   THE MATRIX OF ILLUMINATI - What We Found Will ...
# 6   Secret Societies - The Code of the Illuminati ...
# 7   🔺GTA 5 : MICHAEL THE INDIAN MAFIA ILLUMINATI P...
# 8   Beyonc√© &amp; the Illuminati Conspiracy Theor...
# 9   “Illuminati Could Be Real &amp; ACTIVE” - Abhi...
# 10  Geschichte der Geheimbünde | Illuminati und Fr...
# 11                    Proving the Illuminati is Real!
# 12                               ILLUMINATI THE TRUTH
# 13                Jim Carrey&#39;s Secret Hand Signal
# 14                        ILLUMINATI CONFIRMED?!?!1?!
# 15                    The Illuminati Era of Pop Music
# 16                               Illuminati CONFIRMED
# 17  Illuminati Remix - Kidd Tetoon, Diego Smith, O...
# 18  Illuminati - kiddtetoon feat. Diego Smith (Vid...
# 19                        Lady Gaga Shares Everything
# 20  Décrypteurs | Derrière la conspiration : les I...
# 21  🔺GTA 5 : MICHAEL THE INDIAN MAFIA ILLUMINATI N...
# 22    illuminati headquarters unlocked #shorts #8ball
# 23  Naira Marley &amp; Zlatan - illuminati 👁️ [Off...
# 24  Top 10 Celebrities That are Supposedly in the ...
# 25                             JOINING THE ILLUMINATI
# 26  Iron Man Easter Egg Proves The Illuminati Exis...
# 27       ILLUMINATI - 15 COISAS QUE VOCÊ NÃO SABIA !!
# 28          Avengers Quieren a los Illuminati #Shorts
# 29  Capitán América Se Opone a los Illuminati #Shorts
# 30           The Illuminati D&amp;D Campaign 👁️🧙🏼‍♂️🪦
# 31                      Capitán Geek  2022-10-19T23:00:01Z
# 32                          Sarkodie  2013-08-19T19:43:15Z
# 33                  Hopeless Records  2021-06-10T16:49:27Z
# 34                       Slayy Point  2017-11-22T12:47:49Z
# 35                      Spider-Larry  2022-05-10T17:47:02Z
# 36                       Angry Prash  2017-08-30T14:32:18Z
# 37                         Andrewism  2022-02-02T20:00:24Z
# 38                          SOMOY TV  2022-10-18T10:23:01Z
# 39                     Freddie Gibbs  2021-11-19T05:00:02Z
# 40                     Karin Herrero  2023-03-22T17:05:31Z
# 41           DRAW MY LIFE en Español  2017-06-15T16:00:03Z
# 42                               ILY  2018-09-10T16:00:10Z
# 43                       Você Sabia?  2018-08-09T21:53:30Z
# 44                     WatchMojo.com  2022-08-21T02:00:09Z
# 45                 La Folle Histoire  2020-06-14T12:00:30Z
# 46                            danike  2022-10-04T15:00:13Z
# 47                         Thrillist  2021-09-02T15:00:09Z
# 48                       Moviez Adda  2020-03-04T07:00:07Z
# 49                Cartoon Network UK  2017-10-15T15:00:04Z

# %%
channel_counts = df['Channel'].value_counts()
print(channel_counts)
# Out:
# Channel
# Disturbed Reality           1
# GeoVane                     1
# Wall Street Journal         1
# Joyner Lucas                1
# Vox                         1
# FRONTLINE PBS | Official    1
# CNN                         1
# CBS Mornings                1
# CBN News                    1
# Journeyman Pictures         1
# Name: count, dtype: int64

# %%
videos
# Out:
# [{'Title': 'What Are The Worst ISIS Videos | A Journey Into Depravity &amp; Unimaginable Cruelty',
#   'Channel': 'Disturbed Reality',
#   'Published At': '2023-05-26T19:15:11Z'},
#  {'Title': 'What Happened to ISIS?',
#   'Channel': 'GeoVane',
#   'Published At': '2023-05-09T22:56:23Z'},
#  {'Title': 'Life Inside the ISIS Home Base of Raqqa, Syria',
#   'Channel': 'Wall Street Journal',
#   'Published At': '2014-09-15T21:45:38Z'},
#  {'Title': 'Joyner Lucas ft. Logic - ISIS (ADHD)',
#   'Channel': 'Joyner Lucas',
#   'Published At': '2019-05-23T16:58:10Z'},
#  {'Title': 'The rise of ISIS, explained in 6 minutes',
#   'Channel': 'Vox',
#   'Published At': '2015-12-16T15:30:42Z'},
#  {'Title': 'Confronting ISIS (full documentary) | FRONTLINE',
#   'Channel': 'FRONTLINE PBS | Official',
#   'Published At': '2022-02-09T00:00:07Z'},
#  {'Title': 'Former ISIS hostage gives chilling details of torture',
#   'Channel': 'CNN',
#   'Published At': '2015-10-15T23:07:10Z'},
#  {'Title': 'VICE News gets inside access to ISIS',
#   'Channel': 'CBS Mornings',
#   'Published At': '2014-08-11T12:08:30Z'},
#  {'Title': 'ISIS Is Back and Wants Revenge Against Christians After Quran Burning',
#   'Channel': 'CBN News',
#   'Published At': '2023-02-23T18:26:57Z'},
#  {'Title': 'Inside ISIS and the Iraq Caliphate',
#   'Channel': 'Journeyman Pictures',
#   'Published At': '2014-07-02T07:46:20Z'}]
